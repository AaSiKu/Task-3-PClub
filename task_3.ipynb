# %%
# Importing the necessary libraries

import tensorflow as tf
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense,RandomRotation,RandomZoom,RandomFlip,RandomBrightness,Dropout,Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications.inception_v3 import InceptionV3
from sklearn.model_selection import train_test_split
import pathlib as Path
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import cv2

# %%
# Run only after copying the zip files in /content folder
# !unzip Male.zip
# !unzip Female.zip
# Out:
# Archive:  Male.zip
#    creating: Male/
#   inflating: Male/Screenshot from 2024-05-17 23-27-03.png
#   inflating: Male/Screenshot from 2024-05-17 23-29-09.png
#   inflating: Male/Screenshot from 2024-05-17 23-29-44.png
#   inflating: Male/Pasted image.png
#   inflating: Male/Screenshot from 2024-05-17 23-30-20.png
#   inflating: Male/Screenshot from 2024-05-17 23-30-35.png
#   inflating: Male/Screenshot from 2024-05-17 23-30-56.png
#   inflating: Male/Screenshot from 2024-05-17 23-31-21.png
#   inflating: Male/Screenshot from 2024-05-17 23-36-38.png
#   inflating: Male/Screenshot from 2024-05-17 23-36-57.png
#   inflating: Male/Screenshot from 2024-05-17 23-40-22.png
#   inflating: Male/Screenshot from 2024-05-17 23-40-36.png
#   inflating: Male/Screenshot from 2024-05-17 23-42-53.png
#   inflating: Male/Screenshot from 2024-05-17 23-43-08.png
#   inflating: Male/Screenshot from 2024-05-17 23-43-29.png
#   inflating: Male/Screenshot from 2024-05-17 23-43-56.png
#   inflating: Male/Screenshot from 2024-05-17 23-44-09.png
#   inflating: Male/Screenshot from 2024-05-17 23-44-34.png
#   inflating: Male/Screenshot from 2024-05-17 23-45-40.png
#   inflating: Male/Screenshot from 2024-05-17 23-45-50.png
#   inflating: Male/Screenshot from 2024-05-17 23-46-11.png
#   inflating: Male/Screenshot from 2024-05-17 23-55-41.png
#   inflating: Male/Screenshot from 2024-05-17 23-57-11.png
#   inflating: Male/Screenshot from 2024-05-17 23-58-23.png
#   inflating: Male/Screenshot from 2024-05-17 23-59-29.png
#   inflating: Male/Screenshot from 2024-05-18 00-03-10.png
#   inflating: Male/Screenshot from 2024-05-18 00-06-59.png
#   inflating: Male/Screenshot from 2024-05-18 00-07-34.png
#   inflating: Male/Screenshot from 2024-05-18 00-10-34.png
#   inflating: Male/Screenshot from 2024-05-18 00-10-48.png
#   inflating: Male/Screenshot from 2024-05-18 00-12-48.png
#   inflating: Male/Screenshot from 2024-05-18 00-13-21.png
#   inflating: Male/Screenshot from 2024-05-18 00-13-56.png
#   inflating: Male/Screenshot from 2024-05-18 00-14-29.png
#   inflating: Male/Screenshot from 2024-05-18 00-14-59.png
#   inflating: Male/Screenshot from 2024-05-18 00-15-12.png
#   inflating: Male/Screenshot from 2024-05-18 00-16-24.png
#   inflating: Male/Screenshot from 2024-05-18 00-16-50.png
#   inflating: Male/Screenshot from 2024-05-18 00-17-29.png
#   inflating: Male/Screenshot from 2024-05-18 00-20-38.png
#   inflating: Male/Screenshot from 2024-05-18 00-20-58.png
#   inflating: Male/Screenshot from 2024-05-18 00-21-52.png
#   inflating: Male/Screenshot from 2024-05-18 00-22-15.png
#   inflating: Male/Screenshot from 2024-05-18 00-22-35.png
#   inflating: Male/Screenshot from 2024-05-18 00-24-28.png
#   inflating: Male/Screenshot from 2024-05-18 00-25-07.png
#   inflating: Male/Screenshot from 2024-05-18 00-25-33.png
#   inflating: Male/Screenshot from 2024-05-18 00-25-54.png
#   inflating: Male/Screenshot from 2024-05-18 00-39-31.png
#   inflating: Male/Screenshot from 2024-05-18 00-39-36.png
#   inflating: Male/Screenshot from 2024-05-18 00-39-41.png
#   inflating: Male/Screenshot from 2024-05-18 00-40-22.png
#   inflating: Male/Screenshot from 2024-05-18 00-41-33.png
#   inflating: Male/Screenshot from 2024-05-18 10-58-07.png
#   inflating: Male/Screenshot from 2024-05-18 11-48-55.png
#   inflating: Male/Pasted image 1.png
#   inflating: Male/Pasted image 2.png
#   inflating: Male/Pasted image 3.png
#   inflating: Male/Screenshot from 2024-05-18 11-49-54.png
#   inflating: Male/Screenshot from 2024-05-18 11-49-36.png
#   inflating: Male/Screenshot from 2024-05-18 00-19-53.png
#   inflating: Male/Pasted image 4.png
#   inflating: Male/Pasted image 5.png
#   inflating: Male/Pasted image 6.png
#   inflating: Male/Pasted image 7.png
#   inflating: Male/Pasted image 8.png
#   inflating: Male/Pasted image 9.png
#   inflating: Male/Pasted image 10.png
#   inflating: Male/Pasted image 11.png
#   inflating: Male/Pasted image 12.png
#   inflating: Male/Pasted image 13.png
#   inflating: Male/Pasted image 14.png
#   inflating: Male/Pasted image 15.png
#   inflating: Male/Pasted image 16.png
#   inflating: Male/Pasted image 17.png
#   inflating: Male/Pasted image 18.png
#   inflating: Male/Pasted image 19.png
#   inflating: Male/Pasted image 20.png
#   inflating: Male/Pasted image 21.png
#   inflating: Male/Pasted image 22.png
#   inflating: Male/Pasted image 23.png
#   inflating: Male/Pasted image 24.png
#   inflating: Male/Pasted image 25.png
#   inflating: Male/Pasted image 26.png
#   inflating: Male/Pasted image 27.png
#   inflating: Male/Pasted image 28.png
#   inflating: Male/Pasted image 29.png
#   inflating: Male/Pasted image 30.png
#   inflating: Male/Pasted image 31.png
#   inflating: Male/Pasted image 32.png
#   inflating: Male/Pasted image 33.png
#   inflating: Male/Pasted image 34.png
#   inflating: Male/Pasted image 35.png
#   inflating: Male/Pasted image 36.png
#   inflating: Male/Pasted image 37.png
#   inflating: Male/Pasted image 38.png
#   inflating: Male/Pasted image 39.png
#   inflating: Male/Pasted image 40.png
#   inflating: Male/Pasted image 41.png
#   inflating: Male/Pasted image 42.png
#   inflating: Male/Pasted image 43.png
#   inflating: Male/Pasted image 44.png
#   inflating: Male/Pasted image 45.png
# Archive:  Female.zip
#    creating: Female/
#   inflating: Female/Screenshot from 2024-05-17 23-24-26.png
#   inflating: Female/Screenshot from 2024-05-17 23-24-43.png
#   inflating: Female/Screenshot from 2024-05-17 23-24-57.png
#   inflating: Female/Screenshot from 2024-05-17 23-25-13.png
#   inflating: Female/Screenshot from 2024-05-17 23-25-31.png
#   inflating: Female/Screenshot from 2024-05-17 23-27-24.png
#   inflating: Female/Screenshot from 2024-05-17 23-28-15.png
#   inflating: Female/Screenshot from 2024-05-17 23-32-33.png
#   inflating: Female/Screenshot from 2024-05-17 23-33-00.png
#   inflating: Female/Screenshot from 2024-05-17 23-33-57.png
#   inflating: Female/Pasted image 19.png
#   inflating: Female/Pasted image 20.png
#   inflating: Female/Pasted image 21.png
#   inflating: Female/Pasted image 22.png
#   inflating: Female/Pasted image 23.png
#   inflating: Female/Pasted image 24.png
#   inflating: Female/Pasted image 25.png
#   inflating: Female/Pasted image 26.png
#   inflating: Female/Pasted image 27.png
#   inflating: Female/Pasted image 28.png
#   inflating: Female/Pasted image 29.png
#   inflating: Female/Pasted image 30.png
#   inflating: Female/Pasted image 31.png
#   inflating: Female/Pasted image 32.png
#   inflating: Female/Pasted image 33.png
#   inflating: Female/Pasted image 34.png
#   inflating: Female/Pasted image 35.png
#   inflating: Female/Pasted image 36.png
#   inflating: Female/Pasted image 37.png
#   inflating: Female/Pasted image 38.png
#   inflating: Female/Pasted image 39.png
#   inflating: Female/Pasted image 40.png
#   inflating: Female/Pasted image 41.png
#   inflating: Female/Pasted image 42.png
#   inflating: Female/Pasted image 43.png
#   inflating: Female/Pasted image 44.png
#   inflating: Female/Pasted image 45.png
#   inflating: Female/Pasted image 46.png
#   inflating: Female/Pasted image 47.png
#   inflating: Female/Pasted image 48.png
#   inflating: Female/Pasted image 49.png
#   inflating: Female/Pasted image 50.png
#   inflating: Female/Pasted image 51.png
#   inflating: Female/Pasted image 52.png
#   inflating: Female/Pasted image 53.png
#   inflating: Female/Pasted image 54.png
#   inflating: Female/Pasted image 55.png

# %%
data_dir = Path.Path("/content/")
os.listdir(str(data_dir))
# Out:
# /content

# %%
people_images_dict = {
    'male': list(data_dir.glob('Male/*')),
    'female': list(data_dir.glob('Female/*')),
}

# %%
people_label_dict = {
    'male': 0,
    'female': 1,
}

# %%
X, y = [], []
# Importing the images, converting them to arrays , resizing them so that all images are of same size, and adding labels for each image
for label, images in people_images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(180,180))
        X.append(resized_img)
        y.append(people_label_dict[label])

# %%
len(X)
# Out:
# 208

# %%
X = np.array(X)
y = np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,test_size=0.4)

# %%
X_train.shape,X_test.shape
# Out:
# ((124, 180, 180, 3), (84, 180, 180, 3))

# %%
# Normalizing so that the values in img arrays are between 0 and 1.
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
X_train_scaled.shape
# Out:
# (124, 180, 180, 3)

# %%
model_imagenet = InceptionV3(weights='imagenet',include_top=False,input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step

# %%
model_imagenet = InceptionV3(weights='imagenet',include_top=False,input_shape=(180, 180, 3))

# %%
model_imagenet.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]        0         []
#
#  conv2d_3 (Conv2D)           (None, 89, 89, 32)           864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 89, 89, 32)           96        ['conv2d_3[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 89, 89, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 32)           9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 87, 87, 32)           96        ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 87, 87, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 87, 87, 64)           18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 87, 87, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 87, 87, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 43, 43, 64)           0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 43, 43, 80)           5120      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_3 (Bat  (None, 43, 43, 80)           240       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 43, 43, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 41, 41, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 41, 41, 192)          576       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 41, 41, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_4 (MaxPoolin  (None, 20, 20, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 20, 20, 64)           12288     ['max_pooling2d_4[0][0]']
#
#  batch_normalization_8 (Bat  (None, 20, 20, 64)           192       ['conv2d_11[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 20, 20, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 20, 20, 48)           9216      ['max_pooling2d_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 20, 20, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 20, 20, 48)           144       ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 20, 20, 96)           288       ['conv2d_12[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 20, 20, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 20, 20, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 20, 20, 192)          0         ['max_pooling2d_4[0][0]']
#  Pooling2D)
#
#  conv2d_8 (Conv2D)           (None, 20, 20, 64)           12288     ['max_pooling2d_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 20, 20, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 20, 20, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 20, 20, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 20, 20, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 20, 20, 64)           192       ['conv2d_10[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 20, 20, 96)           288       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 20, 20, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 20, 20, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 20, 20, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 20, 20, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 20, 20, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 20, 20, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 20, 20, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 20, 20, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 20, 20, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 20, 20, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 20, 20, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 20, 20, 96)           288       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 20, 20, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 20, 20, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 20, 20, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_15 (Conv2D)          (None, 20, 20, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 20, 20, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 20, 20, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 20, 20, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 20, 20, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 20, 20, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 20, 20, 96)           288       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 20, 20, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 20, 20, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 20, 20, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 20, 20, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 20, 20, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 20, 20, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 20, 20, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 20, 20, 48)           144       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 20, 20, 96)           288       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 20, 20, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 20, 20, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 20, 20, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_22 (Conv2D)          (None, 20, 20, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 20, 20, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 20, 20, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 20, 20, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 20, 20, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 20, 20, 64)           192       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 20, 20, 96)           288       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 20, 20, 64)           192       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 20, 20, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 20, 20, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 20, 20, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 20, 20, 64)           192       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 20, 20, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 20, 20, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 20, 20, 96)           288       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 20, 20, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 9, 9, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 9, 9, 96)             82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 9, 9, 384)            1152      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 9, 9, 96)             288       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 9, 9, 384)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 9, 9, 96)             0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 9, 9, 288)            0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 9, 9, 768)            0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_5[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 9, 9, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 9, 9, 128)            384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 9, 9, 128)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 9, 9, 128)            114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 9, 9, 128)            384       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 9, 9, 128)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 9, 9, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 9, 9, 128)            114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 9, 9, 128)            384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 9, 9, 128)            384       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 9, 9, 128)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 9, 9, 128)            0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 9, 9, 128)            114688    ['activation_31[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 9, 9, 128)            114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 9, 9, 128)            384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 9, 9, 128)            384       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 9, 9, 128)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 9, 9, 128)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 9, 9, 768)            0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_33 (Conv2D)          (None, 9, 9, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 9, 9, 192)            172032    ['activation_32[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 9, 9, 192)            172032    ['activation_37[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 9, 9, 192)            147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 9, 9, 192)            576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 9, 9, 192)            576       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 9, 9, 192)            576       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 9, 9, 192)            576       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 9, 9, 192)            0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 9, 9, 192)            0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 9, 9, 192)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None,
 768)            0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 4, 4, 768)            0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 4, 4, 192)            0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 4, 4, 2048)           0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21802784 (83.17 MB)
# Trainable params: 21768352 (83.04 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
model_imagenet.trainable = False

# %%
# Adding a data augmentation layer, so that there could be more variety of images in the training data and the model does not overfit.
data_aug_layer = tf.keras.Sequential([
    RandomFlip("horizontal"),
    RandomZoom(0.2),
    RandomRotation(0.1)
])

# %%
model = Sequential()
num_classes = 2
# Add the pre-trained base model
model.add(Input(shape=(180, 180, 3)))
model.add(data_aug_layer)
model.add(model_imagenet)
# Add custom layers on top
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(num_classes))  # Adjust num_classes accordingly

from tensorflow.keras.callbacks import EarlyStopping

# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.build()

# %%
# Upload the saved weights (it takes time to upload the weights as it is a 224 mb file, to see the model in action you can checkout hugging face link)
model.load_weights("model_weights .h5")

# %%
# Uncomment if you have not loaded weights.
# model.fit(X_train_scaled, y_train, epochs=200,batch_size=16,validation_data=(X_test_scaled,y_test),callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 8/8 [==============================] - 8s 391ms/step - loss: 0.0614 - accuracy: 0.9839 - val_loss: 0.3987 - val_accuracy: 0.8929
# Epoch 2/200
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0287 - accuracy: 0.9839 - val_loss: 0.5341 - val_accuracy: 0.8571
# Epoch 3/200
# 8/8 [==============================] - 1s 104ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 0.5864 - val_accuracy: 0.8571
# Epoch 4/200
# 8/8 [==============================] - 1s 128ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 0.6010 - val_accuracy: 0.8571
# Epoch 5/200
# 8/8 [==============================] - 1s 129ms/step - loss: 0.0390 - accuracy: 0.9839 - val_loss: 0.4277 - val_accuracy: 0.8929
# Epoch 6/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0173 - accuracy: 0.9919 - val_loss: 0.5685 - val_accuracy: 0.8452
# Epoch 7/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.4415 - val_accuracy: 0.8929
# Epoch 8/200
# 8/8 [==============================] - 1s 127ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.4373 - val_accuracy: 0.9048
# Epoch 9/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.8690
# Epoch 10/200
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.8690
# Epoch 11/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0349 - accuracy: 0.9919 - val_loss: 0.4556 - val_accuracy: 0.8929
# Epoch 12/200
# 8/8 [==============================] - 0s 66ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.5433 - val_accuracy: 0.8810
# Epoch 13/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.4641 - val_accuracy: 0.9048
# Epoch 14/200
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0101 - accuracy: 0.9919 - val_loss: 0.8220 - val_accuracy: 0.7976
# Epoch 15/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0263 - accuracy: 0.9919 - val_loss: 0.4403 - val_accuracy: 0.9048
# Epoch 16/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0264 - accuracy: 0.9919 - val_loss: 0.8402 - val_accuracy: 0.8214
# Epoch 17/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1240 - accuracy: 0.9677 - val_loss: 0.4753 - val_accuracy: 0.8690
# Epoch 18/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0374 - accuracy: 0.9839 - val_loss: 0.7123 - val_accuracy: 0.7976
# Epoch 19/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.4584 - val_accuracy: 0.8810
# Epoch 20/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.4431 - val_accuracy: 0.8929
# Epoch 21/200
# 8/8 [==============================] - 1s 134ms/step - loss: 0.0247 - accuracy: 0.9839 - val_loss: 0.4140 - val_accuracy: 0.9167
# Epoch 22/200
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.4173 - val_accuracy: 0.9048
# Epoch 23/200
# 8/8 [==============================] - 1s 70ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.9580 - val_accuracy: 0.7857
# Epoch 24/200
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0233 - accuracy: 0.9839 - val_loss: 0.5587 - val_accuracy: 0.8571
# Epoch 25/200
# 8/8 [==============================] - 1s 69ms/step - loss: 0.0219 - accuracy: 0.9919 - val_loss: 0.5294 - val_accuracy: 0.8810
# Epoch 26/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.7148 - val_accuracy: 0.8452
# Epoch 27/200
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4590 - val_accuracy: 0.8929
# Epoch 28/200
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0273 - accuracy: 0.9919 - val_loss: 0.8636 - val_accuracy: 0.8095
# Epoch 29/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0392 - accuracy: 0.9919 - val_loss: 0.5150 - val_accuracy: 0.8690
# Epoch 30/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0234 - accuracy: 0.9919 - val_loss: 0.5638 - val_accuracy: 0.8929
# Epoch 31/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.9167
# Epoch 32/200
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0500 - accuracy: 0.9839 - val_loss: 0.8002 - val_accuracy: 0.7976
# Epoch 33/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.3853 - val_accuracy: 0.8929
# Epoch 34/200
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0284 - accuracy: 0.9839 - val_loss: 0.4890 - val_accuracy: 0.8571
# Epoch 35/200
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0421 - accuracy: 0.9919 - val_loss: 0.5625 - val_accuracy: 0.8810
# Epoch 36/200
# 8/8 [==============================] - 0s 64ms/step - loss: 0.0616 - accuracy: 0.9597 - val_loss: 0.5086 - val_accuracy: 0.8929
# Epoch 37/200
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0201 - accuracy: 0.9919 - val_loss: 1.1755 - val_accuracy: 0.7738
# Epoch 38/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 0.4195 - val_accuracy: 0.9167
# Epoch 39/200
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.3915 - val_accuracy: 0.9167
# Epoch 40/200
# 8/8 [==============================] - 0s 63ms/step - loss: 0.0113 - accuracy: 0.9919 - val_loss: 0.3987 - val_accuracy: 0.9167
# Epoch 41/200
# 8/8 [==============================] - 1s 139ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.4834 - val_accuracy: 0.8929

# %%
#Taking predictions
y_pred = model.predict(X_test_scaled)
y_pred = y_pred.argmax(axis = 1)
y_preds_tensor = y_pred
# Out:
# 3/3 [==============================] - 1s 66ms/step

# %%
def is_equal(y_pred,y):
    if y_pred == y:
        return 1
    else:
        return 0

# %%
class_names = {
    1: 'female',
    0: 'male'
}

# %%
#Vissualizing result

No_of_values_to_predict = 16
plt.figure(figsize=(10,10))
Color = ['r','g']
list_indices = np.random.randint(0,len(X_test_scaled),16)
for x in range(16):
    plt.subplot(4,4,x+1)
    img = cv2.cvtColor(X_test_scaled[list_indices[x]].squeeze().astype(np.float32),cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.title(f"{class_names[y_preds_tensor[list_indices[x]]]}|{class_names[y_test[list_indices[x]]]}",
          c=Color[is_equal(y_preds_tensor[list_indices[x]],y_test[list_indices[x]] )])

# %%
model.save_weights('/content/model_weights.h5')
